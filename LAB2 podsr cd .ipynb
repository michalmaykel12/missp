# %%
import numpy as np

# %%
a_list= [1,2,3,4,5, [1,2,3], "temat"] # nie idealna lista
k_krotka = (1,2,3,4,5, [1,2,3], "temat")
b_list = [1,2,3,4,5]
n_array = np.array(b_list) # wektor numpy

# %%
print(a_list+b_list)
n_array+n_array
# Out:
# [1, 2, 3, 4, 5, [1, 2, 3], 'temat', 1, 2, 3, 4, 5]
# array([ 2,  4,  6,  8, 10])

# %%
a_list[3]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-a1492b151a5c> in <module>
# ----> 1 k_list[3]
#
# NameError: name 'k_list' is not defined

# %%
a_list.append(100)
print(a_list)
# Out:
# [1, 2, 3, 4, 5, [1, 2, 3], 'temat', 100, 100]

# %%
k_krotka[4]
# Out:
# 5

# %%
k_krotka.append(100)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-4da2f0146474> in <module>
# ----> 1 k_krotka.append(100)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
np.array(b_list)+np.array(b_list)
# Out:
# array([ 2,  4,  6,  8, 10])

# %%
n_array = np.array(a_list) # wektor numpy

# %%
n_array
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-923814405e73> in <module>()
# ----> 1 n_array
#
# NameError: name 'n_array' is not defined

# %%
#### Nowosci

studenci_slownik = {123: 123,"Igor":3, "Frankek":5, "Zosia":22,"Julia":[2,21], (1,2):"Krotka"}

# %%
print(studenci_slownik)
# Out:
# {123: 123, 'Igor': 3, 'Frankek': 5, 'Zosia': 22, 'Julia': [2, 21], (1, 2): 'Krotka'}

# %%
studenci_slownik["Zosia"]
# Out:
# 22

# %%
for elementy in studenci_slownik:
    print(elementy)

print("*"*20)
for elementy in studenci_slownik.keys():
    print(elementy)
# Out:
# 123
# Igor
# Frankek
# Zosia
# Julia
# (1, 2)
# ********************
# 123
# Igor
# Frankek
# Zosia
# Julia
# (1, 2)

# %%
for elementy in studenci_slownik.items():
    print(elementy)
# Out:
# ('Igor', 3)
# ('Frankek', 5)
# ('Zosia', 22)
# ('Julia', [2, 21])

# %%
for elementy in studenci_slownik.values():
    print(elementy)
# Out:
# 3
# 5
# 22
# [2, 21]

# %%
studenci_slownik["Cuthulu"]= -1000000
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-793bc4d4c1ef> in <module>()
# ----> 1 studenci_slownik["Cuthulu"]= -1000000
#
# NameError: name 'studenci_slownik' is not defined

# %%
studenci_slownik
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-4e724277ec97> in <module>()
# ----> 1 studenci_slownik
#
# NameError: name 'studenci_slownik' is not defined

# %%
stara_lista = ["Igor", "Franek", "nie_imie", "Ania"]
nowa_lista = [imie for imie in stara_lista if imie[0].isupper()]
print(nowa_lista)
# Out:
# ['Igor', 'Franek', 'Ania']

# %%
automatyczna_lista=[liczba**2 for liczba in range(100) if liczba%4==0]
print(automatyczna_lista)
automatyczna_lista_pary=[(liczba,liczba**2) for liczba in range(100) if liczba%4==0]
print(automatyczna_lista_pary)
# Out:
# [0, 16, 64, 144, 256, 400, 576, 784, 1024, 1296, 1600, 1936, 2304, 2704, 3136, 3600, 4096, 4624, 5184, 5776, 6400, 7056, 7744, 8464, 9216]
# [(0, 0), (4, 16), (8, 64), (12, 144), (16, 256), (20, 400), (24, 576), (28, 784), (32, 1024), (36, 1296), (40, 1600), (44, 1936), (48, 2304), (52, 2704), (56, 3136), (60, 3600), (64, 4096), (68, 4624), (72, 5184), (76, 5776), (80, 6400), (84, 7056), (88, 7744), (92, 8464), (96, 9216)]

# %%
studenci = studenci_slownik.keys()
automatyczny_slownik=dict(para for para in enumerate(studenci))
print(automatyczny_slownik)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-714044271559> in <module>()
# ----> 1 studenci = studenci_slownik.keys()
#       2 automatyczny_slownik=dict(para for para in enumerate(studenci))
#       3 print(automatyczny_slownik)
#
# NameError: name 'studenci_slownik' is not defined

# %%
print(studenci_slownik)
print("Igor" in studenci_slownik)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-ef76eab5783d> in <module>()
# ----> 1 print(studenci_slownik)
#       2 print("Igor" in studenci_slownik)
#
# NameError: name 'studenci_slownik' is not defined

# %%
##### zbiory

a={1,2,3,"Franek"}
b={2,3,4,"Franek"}

# %%
a|b #suma zbiorów, sum of sets
# Out:
# {1, 2, 3, 4, 'Franek'}

# %%
a.add("Franek")
print(a)
# Out:
# {1, 2, 3, 'Franek'}

# %%
1 in a
"Igor" in studenci_slownik
# Out:
# True

# %%
studenci_lista=["Igor_model_"+str(nr) for nr in range(1000)]
print(studenci_lista)
studenci_set = set(studenci_lista)
print(studenci_set)

powtarzajaca_lista = ["Igor" for el in range(1000)]
print(powtarzajaca_lista)
print(set(powtarzajaca_lista))
# Out:
# ['Igor_model_0', 'Igor_model_1', 'Igor_model_2', 'Igor_model_3', 'Igor_model_4', 'Igor_model_5', 'Igor_model_6', 'Igor_model_7', 'Igor_model_8', 'Igor_model_9', 'Igor_model_10', 'Igor_model_11', 'Igor_model_12', 'Igor_model_13', 'Igor_model_14', 'Igor_model_15', 'Igor_model_16', 'Igor_model_17', 'Igor_model_18', 'Igor_model_19', 'Igor_model_20', 'Igor_model_21', 'Igor_model_22', 'Igor_model_23', 'Igor_model_24', 'Igor_model_25', 'Igor_model_26', 'Igor_model_27', 'Igor_model_28', 'Igor_model_29', 'Igor_model_30', 'Igor_model_31', 'Igor_model_32', 'Igor_model_33', 'Igor_model_34', 'Igor_model_35', 'Igor_model_36', 'Igor_model_37', 'Igor_model_38', 'Igor_model_39', 'Igor_model_40', 'Igor_model_41', 'Igor_model_42', 'Igor_model_43', 'Igor_model_44', 'Igor_model_45', 'Igor_model_46', 'Igor_model_47', 'Igor_model_48', 'Igor_model_49', 'Igor_model_50', 'Igor_model_51', 'Igor_model_52', 'Igor_model_53', 'Igor_model_54', 'Igor_model_55', 'Igor_model_56', 'Igor_model_57', 'Igor_model_58', 'Igor_model_59', 'Igor_model_60', 'Igor_model_61', 'Igor_model_62', 'Igor_model_63', 'Igor_model_64', 'Igor_model_65', 'Igor_model_66', 'Igor_model_67', 'Igor_model_68', 'Igor_model_69', 'Igor_model_70', 'Igor_model_71', 'Igor_model_72', 'Igor_model_73', 'Igor_model_74', 'Igor_model_75', 'Igor_model_76', 'Igor_model_77', 'Igor_model_78', 'Igor_model_79', 'Igor_model_80', 'Igor_model_81', 'Igor_model_82', 'Igor_model_83', 'Igor_model_84', 'Igor_model_85', 'Igor_model_86', 'Igor_model_87', 'Igor_model_88', 'Igor_model_89', 'Igor_model_90', 'Igor_model_91', 'Igor_model_92', 'Igor_model_93', 'Igor_model_94', 'Igor_model_95', 'Igor_model_96', 'Igor_model_97', 'Igor_model_98', 'Igor_model_99', 'Igor_model_100', 'Igor_model_101', 'Igor_model_102', 'Igor_model_103', 'Ig
_model_232', 'Igor_model_657', 'Igor_model_339', 'Igor_model_56', 'Igor_model_911', 'Igor_model_21', 'Igor_model_191', 'Igor_model_890', 'Igor_model_867', 'Igor_model_775', 'Igor_model_473', 'Igor_model_665', 'Igor_model_633', 'Igor_model_412', 'Igor_model_988', 'Igor_model_848', 'Igor_model_197', 'Igor_model_109', 'Igor_model_664', 'Igor_model_759', 'Igor_model_3', 'Igor_model_202', 'Igor_model_787',  ...
# ['Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', 'Igor', ...
# {'Igor'}

# %%
# %%timeit
#####Udowadniamy ze przeszukiwanie set jest szybsze od listy
jest = "Igor_999" in studenci_lista
# Out:
# 100000 loops, best of 3: 9.55 µs per loop

# %%
# %%timeit

jest = "Igor_999" in studenci_set
# Out:
# 10000000 loops, best of 3: 33.3 ns per loop

# %% [markdown]
# *kursywa*### Własne typy

# %%
zajecia = [["wf"],
           ["informatyka", "nauka czytania"],
           ["relax", "jedzenie"],
           ["mispy","mispy w domu"],
           ["piateczek", "praca domowa z mispow", "Ilovemispy", "mispy w czasie snu"]
          ]

dnityg= ["Pon","Wto","Sro","Czwar","Pio"]

def dodaj_dwie_liczby(liczba1,liczba2):
    return liczba1+liczba2

# %%
class Pelna():
  nazwa = "stała"
  
pustastan = Pusta()
type(pustostan)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-a773477a6ed5> in <module>()
#       2   nazwa = "stała"
#       3
# ----> 4 pustastan = Pusta()
#       5 type(pustostan)
#
# NameError: name 'Pusta' is not defined

# %%
class DzienZajec():
    """obiekt trzymający dany dzień zajęć i przypisane mu metody"""
    autor = "Igor"
    
    
    def __init__(self, lista_na_dany_dzien, nazwa_dnia): #definicja
        self.lista_zajec= lista_na_dany_dzien
        self.dzien = nazwa_dnia
        

    
    def ile_mispow(self):
        ile_m = sum([1 for zajecie in self.lista_zajec if "misp" in zajecie.lower()])
        return ile_m

    @property #zamienia na wlasciwosc   
    def ile_zajec(self):
        return len(self.lista_zajec)
    
    def __repr__(self):
        zajecia_do_stringa = ", ".join(self.lista_zajec)
        return "W dzien {} mam zajecia: {}".format(self.dzien, zajecia_do_stringa)

# %%
class DzienZajecFanatykaMispow(DzienZajec):
   def kocham_mispy(self):
      print("tak bardzo kocham mispy")

# %%
pio_zajecia = DzienZajec(["piateczek", "praca domowa z mispow", "Ilovemispy", "mispy w czasie snu"],
                        "piatek")

# %%
pio_zajecia.ile_zajec

# %%
print(pio_zajecia)

# %%
pio_zajecia.lista_zajec

# %%
pio_zajecia.lista_zajec.append("MISP")
print(pio_zajecia.lista_zajec)

# %%
pio_zajecia.ile_mispow()

# %%
print(pio_zajecia.lista_zajec)

# %%
pio_zajecia

# %%
print(pio_zajecia.ile_zajec)

# %%
lista_zajec= [DzienZajec(lista_dzien, dzien) for lista_dzien, dzien in 
             zip(zajecia,dnityg)]

# %%
print(lista_zajec)

# %%
posortowane_po_zajeciach=sorted(lista_zajec, key= lambda zajecie: zajecie.ile_zajec)
posortowane_po_mispach=sorted(lista_zajec, key= lambda zajecie: zajecie.ile_mispow())

# %%
print(posortowane_po_zajeciach)

# %%
print(posortowane_po_mispach)

# %% [markdown]
# ## Challenge 1
#
# Stworz typ NumerTelefonu
#
#  -- przy tworzeniu sprawdza czy właściwy numer (Polski) jeśli nie pisze, że error (ew. Exception)
#
#  -- gdy printuję to mi pisze polskimi słowami i.e. "jeden, pięć, siedem, zero"
#
#  -- gdy wywołuję właściwość wojewodzwtwo, podaje mi wojewodztwo ew. ze to komorkowy

# %% [markdown]
# sprawdzmy czy podany numer jest prawidłowy, województwo Łódzkie

# %%
numer_lodz = NumerTelefonu("426877868")
>>> "prawidlowy numer"

numer_lodz.wojewodztwo 
>>> "Lodz"

print(numer_lodz)
>>> "cztery dwa sześć osiem siedem siedem osiem sześć osiem"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-a82e69e66e00> in <module>()
# ----> 1 numer_lodz = NumerTelefonu("426877868")
#       2 "prawidlowy numer"
#       3
#       4 numer_lodz.wojewodztwo
#       5 "Lodz"
#
# NameError: name 'NumerTelefonu' is not defined

# %%
class Numertelefonu():
# Out:
#   File "<ipython-input-6-ecfcd80a306e>", line 1
#     class Numertelefonu():
#                           ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# ## 1.sprawdzmy czy numer jest polski i czy jest prawdziwy

# %%
def __init__(self,nr):
        self.numertelefonu = nr
        if len(self.numertelefonu) == 9:
            print("Ten numer jest prawdziwy")
        else:
            print("Błąd, numer za krótki lub za długi")

# %% [markdown]
# ## 2. Tu mamy  wyprintowanie numeru w postaci ciągu słów odpowiadającym konkretnym cyfrom numeru nelefonu.

# %%
def __repr__(self):
        cyfry = ["zero","jeden","dwa","trzy","cztery","pięć","sześć","siedem","osiem","dziewięć"]
        nr = ""
        for cyfra in self.numertelefonu:
            nr = nr + "" + cyfry[int(cyfra)]
        return nr

# %% [markdown]
# ## 3.   ta częśc odpowiada za podanie numeru kierunkowego.

# %%
def wojewodztwo(self):
        nrkierunkowy = self.numertelefonu[0] + self.numertelefonu[1]
        nrkierunkowe = {"42":"łódzkie","22":"mazowieckie","12":"małopolskie","61":"wielkoposkie","58":"pomorskie"}
        try:
            kierunek = nrkierunkowe[nrkierunkowy]
        except KeyError:
            kierunek = "komórki"
        return kierunek

# %% [markdown]
# ## Kod połączony

# %%
class Numertelefonu():
#### 1.
    def __init__(self,nr):
        self.numertelefonu = nr
        if len(self.numertelefonu) == 9:
            print("Ten numer jest prawdziwy")
        else:
            print("Błąd, numer za krótki lub za długi")
#### 2.
    def __repr__(self):
        cyfry = ["zero","jeden","dwa","trzy","cztery","pięć","sześć","siedem","osiem","dziewięć"]
        nr = ""
        for cyfra in self.numertelefonu:
            nr = nr + "" + cyfry[int(cyfra)]
        return nr
### 3.
    def wojewodztwo(self):
        nrkierunkowy = self.numertelefonu[0] + self.numertelefonu[1]
        nrkierunkowe = {"42":"łódzkie","22":"mazowieckie","12":"małopolskie","61":"wielkoposkie","58":"pomorskie"}
        try:
            kierunek = nrkierunkowe[nrkierunkowy]
        except KeyError:
            kierunek = "komórki"
        return kierunek

# %% [markdown]
# ## weryfikacja wpisanego numeru

# %%
wybrany_numer = Numertelefonu("425555555")
# Out:
# Ten numer jest prawdziwy

# %% [markdown]
# ## sprawdzenie  województwa z którego  pochodzi numer

# %%
print("Pochodzi z " + wybrany_numer.wojewodztwo())
# Out:
# Pochodzi z łódzkie

# %%
print(wojewodztwo)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-d65d621f15d1> in <module>()
# ----> 1 print(wojewodztwo)
#
# NameError: name 'wojewodztwo' is not defined
